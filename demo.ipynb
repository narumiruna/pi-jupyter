# %% [markdown]
# # Pi Jupyter Preview Demo
#
# This notebook is a small fixture for the **pi-jupyter** extension.
#
# Open it in Pi with:
#
# ```text
# /jupyter-preview demo.ipynb
# ```
#
# The right-side panel should show markdown cells, code cells, execution counts, normal text output, rich-output placeholders, and errors.

# %%
name = "Pi"
print(f"Hello from {name}!")
print("This stdout stream should appear in the preview.")
# Out:
# Hello from a notebook cell!
# This stdout stream should appear in the preview.

# %% [markdown]
# ## A longer markdown cell
#
# The extension wraps long lines to the right-side overlay width. This paragraph is intentionally verbose so you can resize the terminal and confirm that the panel still keeps every rendered line within the available width.
#
# - Bullet one
# - Bullet two
# - Bullet three

# %%
result = {"alpha": 1, "beta": [2, 3, 5], "status": "ok"}
result
# Out:
# {'alpha': 1, 'beta': [2, 3, 5], 'status': 'ok'}

# %%
# Rich image output demo.
# The terminal preview shows text/plain when present, or an [image/png output] placeholder.
display("pretend chart")

# %%
# Error output demo
1 / 0
# Out:
# Traceback (most recent call last):
#   File "<ipython-input-4>", line 1, in <module>
#     1 / 0
# ZeroDivisionError: division by zero

# %%
# Unexecuted cell
numbers = [1, 2, 3, 4]
sum(numbers)
